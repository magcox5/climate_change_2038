# %% [markdown]
# # Temperature Population Sea Level and Emissions
# ### Notebook to combine .csv datasets into one sqlite database for Project 2

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# File to Load  
temperature_data_to_load = "data/temp_data.csv"
population_data_to_load = "data/population_data.csv"
sealevel_data_to_load = "data/sealevel_data.csv"
co2_data_to_load = "data/CO2_data.csv"

# Read Data  
temperature_data = pd.read_csv(temperature_data_to_load)
population_data = pd.read_csv(population_data_to_load)
sealevel_data = pd.read_csv(sealevel_data_to_load)
co2_data = pd.read_csv(co2_data_to_load)

# %%
#Temp Data Molly C.
temperature_data.head(5)
# Out:
#    Year  LandAndOceanAverageTemperature  LandAndOceanAverageTemperatureUncertainty
# 0  1993                       15.466417                                   0.059167
# 1  1994                       15.535000                                   0.058583
# 2  1995                       15.637833                                   0.060417
# 3  1996                       15.524667                                   0.059500
# 4  1997                       15.713833                                   0.059167

# %%
#Population Data John B. 
population_data.head(5)
# Out:
#    Unnamed: 0  Year  population_millions
# 0           0  1993          5581597.598
# 1           1  1994          5663150.428
# 2           2  1995          5744212.930
# 3           3  1996          5824891.931
# 4           4  1997          5905045.647

# %%
#Sealevel Data Melissa W. 
sealevel_data.head(5)
# Out:
#    Year       GMSL
# 0  1993  90.471622
# 1  1994  89.516216
# 2  1995  87.334722
# 3  1996  85.473243
# 4  1997  99.442432

# %%
#C02 Data - Kat A. 
co2_data.head(5)
# Out:
#    Year  CO2_emissions_tons_per_capita
# 0  1993                     869.636645
# 1  1994                     863.100924
# 2  1995                     858.225479
# 3  1996                     859.062572
# 4  1997                     867.379574

# %%
# Use Glob to concat
import matplotlib.pyplot as plt
from glob import glob

# %%
# Combine Files 
climate_files = sorted(glob('data/*_data.csv'))

# %%
# Review Data 
climate_files
# Out:
# ['data\\CO2_data.csv',
#  'data\\population_data.csv',
#  'data\\sealevel_data.csv',
#  'data\\temp_data.csv']

# %%
# Concat Data in Files 
climate_data = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in climate_files), sort= True,  axis=1) 

climate_data
# Out:
#     Year  CO2_emissions_tons_per_capita           filename  Unnamed: 0  Year  population_millions                  filename  Year        GMSL                filename  Year  LandAndOceanAverageTemperature  LandAndOceanAverageTemperatureUncertainty            filename
# 0   1993                     869.636645  data\CO2_data.csv           0  1993          5581597.598  data\population_data.csv  1993   90.471622  data\sealevel_data.csv  1993                       15.466417                                   0.059167  data\temp_data.csv
# 1   1994                     863.100924  data\CO2_data.csv           1  1994          5663150.428  data\population_data.csv  1994   89.516216  data\sealevel_data.csv  1994                       15.535000                                   0.058583  data\temp_data.csv
# 2   1995                     858.225479  data\CO2_data.csv           2  1995          5744212.930  data\population_data.csv  1995   87.334722  data\sealevel_data.csv  1995                       15.637833                                   0.060417  data\temp_data.csv
# 3   1996                     859.062572  data\CO2_data.csv           3  1996          5824891.931  data\population_data.csv  1996   85.473243  data\sealevel_data.csv  1996                       15.524667                                   0.059500  data\temp_data.csv
# 4   1997                     867.379574  data\CO2_data.csv           4  1997          5905045.647  data\population_data.csv  1997   99.442432  data\sealevel_data.csv  1997                       15.713833                                   0.059167  data\temp_data.csv
# 5   1998                     866.162913  data\CO2_data.csv           5  1998          5984794.075  data\population_data.csv  1998   96.977297  data\sealevel_data.csv  1998                       15.826000                                   0.063000  data\temp_data.csv
# 6   1999                     854.147358  data\CO2_data.csv           6  1999          6064239.033  data\population_data.csv  1999   87.769459  data\sealevel_data.csv  1999                       15.600333                                   0.063333  data\temp_data.csv
# 7   2000                     878.764146  data\CO2_data.csv           7  2000          6143493.806  data\population_data.csv  2000   86.657297  data\sealevel_data.csv  2000                       15.610667                                   0.063500  data\temp_data.csv
# 8   2001                     888.096012  data\CO2_data.csv           8  2001          6222626.531  data\population_data.csv  2001   84.688378  data\sealevel_data.csv  2001                       15.767500                                   0.064583  data\temp_data.csv
# 9   2002                     884.272209  data\CO2_data.csv           9  2002          6301773.172  data\population_data.csv  2002   85.895278  data\sealevel_data.csv  2002                       15.829167                                   0.062917  data\temp_data.csv
# 10  2003                     907.525692  data\CO2_data.csv          10  2003          6381185.141  data\population_data.csv  2003   87.178919  data\sealevel_data.csv  2003                       15.826583                                   0.064333  data\temp_data.csv
# 11  2004                     915.658632  data\CO2_data.csv          11  2004          6461159.391  data\population_data.csv  2004   86.263784  data\sealevel_data.csv  2004                       15.757250                                   0.061250  data\temp_data.csv
# 12  2005                     921.000446  data\CO2_data.csv          12  2005          6541906.956  data\population_data.csv  2005   85.427838  data\sealevel_data.csv  2005                       15.879250                                   0.060833  data\temp_data.csv
# 13  2006                     933.068635  data\CO2_data.csv          13  2006          6623517.917  data\population_data.csv  2006   86.161389  data\sealevel_data.csv  2006                       15.813500                                   0.061000  data\temp_data.csv
# 14  2007                     944.312222  data\CO2_data.csv          14  2007          6705946.643  data\population_data.csv  2007   85.265946  data\sealevel_data.csv  2007                       15.827333                                   0.059083  data\temp_data.csv
# 15  2008                     943.559582  data\CO2_data.csv          15  2008          6789088.672  data\population_data.csv  2008   86.838889  data\sealevel_data.csv  2008                       15.721250                                   0.057250  data\temp_data.csv
# 16  2009                     898.608885  data\CO2_data.csv          16  2009          6872766.988  data\population_data.csv  2009   85.634054  data\sealevel_data.csv  2009                       15.827167                                   0.058917  data\temp_data.csv
# 17  2010                     916.898995  data\CO2_data.csv          17  2010          6956823.588  data\population_data.csv  2010   87.830811  data\sealevel_data.csv  2010                       15.895500                                   0.058583  data\temp_data.csv
# 18  2011                     907.572218  data\CO2_data.csv          18  2011          7041194.168  data\population_data.csv  2011   89.016757  data\sealevel_data.csv  2011                       15.769500                                   0.059000  data\temp_data.csv
# 19  2012                     907.679408  data\CO2_data.csv          19  2012          7125827.957  data\population_data.csv  2012   87.514324  data\sealevel_data.csv  2012                       15.802333                                   0.061500  data\temp_data.csv
# 20  2013                     893.012832  data\CO2_data.csv          20  2013          7210582.041  data\population_data.csv  2013   87.777297  data\sealevel_data.csv  2013                       15.854417                                   0.064667  data\temp_data.csv
# 21  2014                     890.230156  data\CO2_data.csv          21  2014          7295290.759  data\population_data.csv  2014   88.426667  data\sealevel_data.csv  2014                       15.913000                                   0.063167  data\temp_data.csv
# 22  2015                     901.399532  data\CO2_data.csv          22  2015          7379796.967  data\population_data.csv  2015  100.599189  data\sealevel_data.csv  2015                       16.058583                                   0.060833  data\temp_data.csv

# %%
#Selecting the columns we want 
climate_combined = climate_data[['Year', 
                            'CO2_emissions_tons_per_capita',
                            'population_millions', 
                            'GMSL', 
                            'LandAndOceanAverageTemperature',
                            'LandAndOceanAverageTemperatureUncertainty']]
climate_combined
# Out:
#     Year  Year  Year  Year  CO2_emissions_tons_per_capita  population_millions        GMSL  LandAndOceanAverageTemperature  LandAndOceanAverageTemperatureUncertainty
# 0   1993  1993  1993  1993                     869.636645          5581597.598   90.471622                       15.466417                                   0.059167
# 1   1994  1994  1994  1994                     863.100924          5663150.428   89.516216                       15.535000                                   0.058583
# 2   1995  1995  1995  1995                     858.225479          5744212.930   87.334722                       15.637833                                   0.060417
# 3   1996  1996  1996  1996                     859.062572          5824891.931   85.473243                       15.524667                                   0.059500
# 4   1997  1997  1997  1997                     867.379574          5905045.647   99.442432                       15.713833                                   0.059167
# 5   1998  1998  1998  1998                     866.162913          5984794.075   96.977297                       15.826000                                   0.063000
# 6   1999  1999  1999  1999                     854.147358          6064239.033   87.769459                       15.600333                                   0.063333
# 7   2000  2000  2000  2000                     878.764146          6143493.806   86.657297                       15.610667                                   0.063500
# 8   2001  2001  2001  2001                     888.096012          6222626.531   84.688378                       15.767500                                   0.064583
# 9   2002  2002  2002  2002                     884.272209          6301773.172   85.895278                       15.829167                                   0.062917
# 10  2003  2003  2003  2003                     907.525692          6381185.141   87.178919                       15.826583                                   0.064333
# 11  2004  2004  2004  2004                     915.658632          6461159.391   86.263784                       15.757250                                   0.061250
# 12  2005  2005  2005  2005                     921.000446          6541906.956   85.427838                       15.879250                                   0.060833
# 13  2006  2006  2006  2006                     933.068635          6623517.917   86.161389                       15.813500                                   0.061000
# 14  2007  2007  2007  2007                     944.312222          6705946.643   85.265946                       15.827333                                   0.059083
# 15  2008  2008  2008  2008                     943.559582          6789088.672   86.838889                       15.721250                                   0.057250
# 16  2009  2009  2009  2009                     898.608885          6872766.988   85.634054                       15.827167                                   0.058917
# 17  2010  2010  2010  2010                     916.898995          6956823.588   87.830811                       15.895500                                   0.058583
# 18  2011  2011  2011  2011                     907.572218          7041194.168   89.016757                       15.769500                                   0.059000
# 19  2012  2012  2012  2012                     907.679408          7125827.957   87.514324                       15.802333                                   0.061500
# 20  2013  2013  2013  2013                     893.012832          7210582.041   87.777297                       15.854417                                   0.064667
# 21  2014  2014  2014  2014                     890.230156          7295290.759   88.426667                       15.913000                                   0.063167
# 22  2015  2015  2015  2015                     901.399532          7379796.967  100.599189                       16.058583                                   0.060833

# %%
#Re-Check the columns 
climate_combined.columns
# Out:
# Index(['Year', 'Year', 'Year', 'Year', 'CO2_emissions_tons_per_capita', 'population_millions', 'GMSL', 'LandAndOceanAverageTemperature', 'LandAndOceanAverageTemperatureUncertainty'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-1c4832d37fc4> in <module>
#       1 #Removing Duplicates
# ----> 2 climate_combined = climate_combined.reset_index().T.drop_duplicates().reset_index(climate_combined).T
#       3 climate_combined
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4653             if not isinstance(level, (tuple, list)):
#    4654                 level = [level]
# -> 4655             level = [self.index._get_level_number(lev) for lev in level]
#    4656             if len(level) < self.index.nlevels:
#    4657                 new_index = self.index.droplevel(level)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4653             if not isinstance(level, (tuple, list)):
#    4654                 level = [level]
# -> 4655             level = [self.index._get_level_number(lev) for lev in level]
#    4656             if len(level) < self.index.nlevels:
#    4657                 new_index = self.index.droplevel(level)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_level_number(self, level)
#    1561
#    1562     def _get_level_number(self, level):
# -> 1563         self._validate_index_level(level)
#    1564         return 0
#    1565
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1553                     "Too many levels:" " Index has only 1 level, not %d" % (level + 1)
#    1554                 )
# -> 1555         elif level != self.name:
#    1556             raise KeyError(
#    1557                 "Requested level ({}) does not match index name ({})".format(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
new_climate_data = climate_combined.drop_duplicates(subset ="Year", 
                     keep = False, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# displaying data 
new_climate_data.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-09a667bbafd6> in <module>
#       1 # displaying data
# ----> 2 new_climate_data.columns
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
climate_combined.drop(climate_combined.columns[[2,3]], axis = 1)

# %%
climate_climate_data = climate_combined

climate_climate_data.rename(columns={'Year':'year',  
                              'Avg Temp':'LandAndOceanAverageTemperature',
                             'Emissions':'CO2_emissions_tons_per_capita',
                             'GMSL':'Avg GMSL',
                             'Avg Population in mil':'population_millions'} )
climate_data

# %%
#Save it all into one file
climate_combined.to_csv('data\combinedclimatedata.csv')
