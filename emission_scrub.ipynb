# %%
# Import dependencies 
import pandas as pd 
import csv

# %%
# read from our original csv files and preview it
data = pd.read_csv("data/co-emissions-per-capita.csv")
data.head(5)
# Out:
#         Entity Code  Year  Per capita CO₂ emissions (tonnes per capita)
# 0  Afghanistan  AFG  1949                                      0.001912
# 1  Afghanistan  AFG  1950                                      0.010871
# 2  Afghanistan  AFG  1951                                      0.011684
# 3  Afghanistan  AFG  1952                                      0.011544
# 4  Afghanistan  AFG  1953                                      0.013218

# %%
# Check on how many years actually listed on the data 
data.groupby(['Year']).groups.keys()
# Out:
# dict_keys([1751, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %%
# rename our columns - eliminate space and updte it with under score
# look at the data head 
data = data.rename(columns={"Per capita CO₂ emissions (tonnes per capita)" : "CO2_emissions_tons_per_capita"})
data.head(5)
# Out:
#         Entity Code  Year  CO2_emissions_tons_per_capita
# 0  Afghanistan  AFG  1949                       0.001912
# 1  Afghanistan  AFG  1950                       0.010871
# 2  Afghanistan  AFG  1951                       0.011684
# 3  Afghanistan  AFG  1952                       0.011544
# 4  Afghanistan  AFG  1953                       0.013218

# %%
# group our data by Year and sum total emmission based on the year. 
data = data.groupby(["Year"]).sum()
data.reset_index()
# Out:
#      Year  CO2_emissions_tons_per_capita
# 0    1751                       0.011522
# 1    1800                       2.309247
# 2    1801                       2.253478
# 3    1802                       4.337327
# 4    1803                       2.475849
# ..    ...                            ...
# 214  2013                     893.012832
# 215  2014                     890.230156
# 216  2015                     901.399532
# 217  2016                     899.315595
# 218  2017                     908.860532
#
# [219 rows x 2 columns]

# %%
# use iloc to choose get a clean csv files to match our teammate's data 
# clean file has to be from 1993 - 2015
clean_data = data.iloc[194:217, : ]
clean_data
# Out:
#       CO2_emissions_tons_per_capita
# Year
# 1993                     869.636645
# 1994                     863.100924
# 1995                     858.225479
# 1996                     859.062572
# 1997                     867.379574
# 1998                     866.162913
# 1999                     854.147358
# 2000                     878.764146
# 2001                     888.096012
# 2002                     884.272209
# 2003                     907.525692
# 2004                     915.658632
# 2005                     921.000446
# 2006                     933.068635
# 2007                     944.312222
# 2008                     943.559582
# 2009                     898.608885
# 2010                     916.898995
# 2011                     907.572218
# 2012                     907.679408
# 2013                     893.012832
# 2014                     890.230156
# 2015                     901.399532

# %%
# safe our clean files into a new csv files to be use for our machine learning
clean_data.to_csv("data/CO2_data.csv")

# %%
#import depedencies needed to test our predict linear regression
import warnings 
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
from sklearn.linear_model import LinearRegression

# %%
emission = pd.read_csv("data/CO2_data.csv")
emission.head()
# Out:
#    Year  CO2_emissions_tons_per_capita
# 0  1993                     869.636645
# 1  1994                     863.100924
# 2  1995                     858.225479
# 3  1996                     859.062572
# 4  1997                     867.379574

# %%
emission.dtypes
# Out:
# Year                               int64
# CO2_emissions_tons_per_capita    float64
# dtype: object

# %%
X = emission["Year"]
y = emission["CO2_emissions_tons_per_capita"].values.reshape(-1,1)
print(X.shape, y.shape)
# Out:
# (23,) (23, 1)

# %%
data = pd.read_csv('data/CO2_data.csv')  # load data set
X = data.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = data.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
#Plot 
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.xlim(1992, 2016)
plt.xlabel('Years')
plt.ylabel('Total CO2 Emission (Tons per capita)')
plt.title('CO2 emission overtime')
fig1 = plt.gcf()
fig1.savefig("images/CO2_emission_overtime.png")

# %%
# read from our original csv files, rename one of the column, and preview it
co2_ppm_data = pd.read_csv("data/co2-concentration-long-term.csv")
co2_ppm_data = data.rename(columns={"CO₂ concentration (parts per million)" : "CO2_concentration_per_million"})
co2_ppm_data.head(5)
# Out:
#    Year  CO2_emissions_tons_per_capita
# 0  1993                     869.636645
# 1  1994                     863.100924
# 2  1995                     858.225479
# 3  1996                     859.062572
# 4  1997                     867.379574

# %%
# select only the range year for the data we want to use
co2_ppm_data = co2_ppm_data.iloc[1845:1868, : ]
co2_ppm_clean = co2_ppm_data.reset_index(drop=True)

# %%
co2_ppm_clean = co2_ppm_clean.drop(["Entity", "Code"], axis =1)
# Out:
# -------------------------------------------------------------
# KeyError                    Traceback (most recent call last)
# <ipython-input-23-c50145a29dbf> in <module>
# ----> 1 co2_ppm_clean = co2_ppm_clean.drop(["Entity", "Code"], axis =1)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Entity' 'Code'] not found in axis"

# %%
co2_ppm_clean
# Out:
#     Year  CO2_concentration_per_million
# 0   1993                         357.10
# 1   1994                         358.83
# 2   1995                         360.82
# 3   1996                         362.61
# 4   1997                         363.73
# 5   1998                         366.70
# 6   1999                         368.38
# 7   2000                         369.55
# 8   2001                         371.14
# 9   2002                         373.28
# 10  2003                         375.80
# 11  2004                         377.52
# 12  2005                         379.80
# 13  2006                         381.90
# 14  2007                         383.79
# 15  2008                         385.60
# 16  2009                         387.43
# 17  2010                         389.90
# 18  2011                         391.65
# 19  2012                         393.85
# 20  2013                         396.52
# 21  2014                         398.65
# 22  2015                         400.83

# %%
# safe our clean files into a new csv files to be use for our machine learning
co2_ppm_clean.to_csv("data/co2_ppm.csv")

# %%
data = pd.read_csv('data/co2_ppm.csv')  # load data set
data.h

# %%
data.head()
# Out:
#    Unnamed: 0  Year  CO2_concentration_per_million
# 0           0  1993                         357.10
# 1           1  1994                         358.83
# 2           2  1995                         360.82
# 3           3  1996                         362.61
# 4           4  1997                         363.73

# %%
ppm_data = data.iloc[:, 1:]
ppm_data
# Out:
#     Year  CO2_concentration_per_million
# 0   1993                         357.10
# 1   1994                         358.83
# 2   1995                         360.82
# 3   1996                         362.61
# 4   1997                         363.73
# 5   1998                         366.70
# 6   1999                         368.38
# 7   2000                         369.55
# 8   2001                         371.14
# 9   2002                         373.28
# 10  2003                         375.80
# 11  2004                         377.52
# 12  2005                         379.80
# 13  2006                         381.90
# 14  2007                         383.79
# 15  2008                         385.60
# 16  2009                         387.43
# 17  2010                         389.90
# 18  2011                         391.65
# 19  2012                         393.85
# 20  2013                         396.52
# 21  2014                         398.65
# 22  2015                         400.83

# %%
data = pd.read_csv('data/CO2_data.csv')  # load data set
X = data.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = data.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions
# Out:
# Empty DataFrame
# Columns: [Year, CO2_emissions_tons_per_capita]
# Index: []

# %%
#Plot 
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.xlim(1992, 2016)
plt.xlabel('Years')
plt.ylabel('CO2 per million')
plt.title('CO2 Concentration per Million')
fig1 = plt.gcf()
fig1.savefig("images/CO2_emission_ppm.png")
