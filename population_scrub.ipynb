# %% [markdown]
# Population Data

# %%
# Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Name of the CSV file
file = 'data/population_data.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'population_millions'], dtype='object')

# %%
pop_data = df.drop(columns={'Unnamed: 0'})
pop_data
# Out:
#     Year  population_millions
# 0   1993          5581597.598
# 1   1994          5663150.428
# 2   1995          5744212.930
# 3   1996          5824891.931
# 4   1997          5905045.647
# 5   1998          5984794.075
# 6   1999          6064239.033
# 7   2000          6143493.806
# 8   2001          6222626.531
# 9   2002          6301773.172
# 10  2003          6381185.141
# 11  2004          6461159.391
# 12  2005          6541906.956
# 13  2006          6623517.917
# 14  2007          6705946.643
# 15  2008          6789088.672
# 16  2009          6872766.988
# 17  2010          6956823.588
# 18  2011          7041194.168
# 19  2012          7125827.957
# 20  2013          7210582.041
# 21  2014          7295290.759
# 22  2015          7379796.967

# %%
population_data = pop_data.rename(columns={'year': 'Year'})
population_data
# Out:
#     Year  population_millions
# 0   1993          5581597.598
# 1   1994          5663150.428
# 2   1995          5744212.930
# 3   1996          5824891.931
# 4   1997          5905045.647
# 5   1998          5984794.075
# 6   1999          6064239.033
# 7   2000          6143493.806
# 8   2001          6222626.531
# 9   2002          6301773.172
# 10  2003          6381185.141
# 11  2004          6461159.391
# 12  2005          6541906.956
# 13  2006          6623517.917
# 14  2007          6705946.643
# 15  2008          6789088.672
# 16  2009          6872766.988
# 17  2010          6956823.588
# 18  2011          7041194.168
# 19  2012          7125827.957
# 20  2013          7210582.041
# 21  2014          7295290.759
# 22  2015          7379796.967

# %%
population_data.to_csv("data/population_data.csv")

# %%
from sklearn.linear_model import LinearRegression

# %%
data = population_data # load data set
X = data.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = data.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.xlabel('Years')
plt.ylabel('Global Population (in millions)')
plt.title('Population Growth Time')
plt.show()
